# %%
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import decode_predictions
from keras.applications.resnet50 import preprocess_input
from keras.preprocessing.image import load_img, img_to_array

# %%
resnet50 = ResNet50()

# %%
img = load_img('dog.webp', target_size=(224,224))

# %%
#import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\Asus'

# %%
img;

# %%
img = img_to_array(img)

# %%
img = img.reshape(1,224,224,3)

# %%
img.shape
# Out:
# (1, 224, 224, 3)

# %%
img = preprocess_input(img)

# %%
pred = resnet50.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
pred;

# %%
decode_predictions(pred)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 3us/step
# [[('n02089973', 'English_foxhound', np.float32(0.46194088)),
#   ('n02088364', 'beagle', np.float32(0.35312337)),
#   ('n02089867', 'Walker_hound', np.float32(0.18015972)),
#   ('n02088238', 'basset', np.float32(0.0023541017)),
#   ('n02088466', 'bloodhound', np.float32(0.0006999578))]]

# %%
from keras.utils import plot_model

# %%
plot_model(resnet50, show_layer_names=True, show_trainable=True)
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.

# %%
resnet50.trainable
# Out:
# True

# %%
labels = ['airplane','automobile','bird','cat','deer','dog',
         'frog','horse','ship','truck']

# %%
resnet50 = ResNet50(include_top=False, input_shape=(32,32,3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 34s 0us/step

# %%
from keras.layers import Flatten, Dense

# %%
#Flatten output layer of ResNet
flattened = Flatten()(resnet50.output)

#fully connected layer-1
fc1 = Dense(128, activation = 'relu', name = 'AddedDense1')(flattened)

#fully connected layer, output layer
fc2 = Dense(10, activation = 'softmax', name = 'AddedDense2')(fc1)

# %%
resnet50.trainable = False

# %%
from keras.models import Model

# %%
model = Model(inputs = resnet50.inputs, outputs = fc2)

# %%
plot_model(model, show_layer_name = True, show_trainable = True) ,#needs graphviz
# Out:
# You must install graphviz (see instructions at https://graphviz.gitlab.io/download/) for `plot_model` to work.
# (None,)

# %%
from keras.datasets import cifar10

# %%
(x_train,y_train),(x_test,y_test) = cifar10.load_data()

# %%
model.compile(loss = 'sparse_categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs = 2)
# Out:
# Epoch 1/2
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 133s 81ms/step - accuracy: 0.5516 - loss: 1.3009
# Epoch 2/2
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 125s 80ms/step - accuracy: 0.6227 - loss: 1.0715

# %%
# Add custom layers on top
flattened = Flatten()(resnet50.output)
fc1 = Dense(128, activation='relu', name="AddedDense1")(flattened)
fc2 = Dense(64, activation='relu', name="AddedDense2")(fc1)
fc3 = Dense(10, activation='softmax', name="OutputLayer")(fc2)

# Build final model
model = Model(inputs=resnet50.input, outputs=fc3)

# Compile
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Train
model.fit(x_train, y_train, epochs=2, batch_size=32)
# Out:
# Epoch 1/2
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 131s 80ms/step - accuracy: 0.5439 - loss: 1.3015
# Epoch 2/2
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 126s 81ms/step - accuracy: 0.6188 - loss: 1.0816
